# %% [markdown]
# <a href="https://colab.research.google.com/github/gabifiap/sprint1.PAI/blob/main/Perguntas_teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Testando possíveis dúvidas e respostas obtidas pela IA já treinada com os datasets.

# %%
MODELO_CUSTOM = "Guia-Goodwe"

# Perguntas inéditas — NÃO estavam no dataset de treino
testes = [
    "Tenho um comércio com 5 carregadores GW7K, mas meu disjuntor geral não suporta todos ligados no máximo. Como o ChargeGrid resolve isso sem eu precisar trocar a fiação?",
    "Se eu chegar com meu carro elétrico às 18h em um ponto de carregamento e o sistema estiver em Modo de Prioridade Solar, o que acontece com a velocidade da minha recarga?",
    "A IA consegue prever quando o eletroposto vai estar mais lotado?",
    "O que o sistema faz se eu tentar carregar meu carro e o prédio já estiver usando muita energia?",
    "Quais os benefícios de usar o Modo de Operação 2 (Prioridade Solar)?",
    "Estou vendo faíscas saindo do conector do carro agora, o que eu faço?",
    "O carregador parou de funcionar e tem uma luz vermelha piscando, qual o procedimento?"
]

print("=" * 60)
print("🧪 TESTES — GUIA GOODWE")
print("=" * 60)

for pergunta in testes:
    resposta = perguntar(MODELO_CUSTOM, pergunta)
    print(f"\n👤 {pergunta}")
    print(f"🤖 {resposta}")
    print("-" * 60)
# Out:
# ============================================================
# 🧪 TESTES — GUIA GOODWE
# ============================================================
#
# 👤 Tenho um comércio com 5 carregadores GW7K, mas meu disjuntor geral não suporta todos ligados no máximo. Como o ChargeGrid resolve isso sem eu precisar trocar a fiação?
# 🤖 O ChargeGrid Intelligence tem uma funcionalidade chamada "Orquestração de Potência" que permite distribuir a carga entre os carregadores, evitando que um único disjuntor seja sobrecarregado. Isso garante a segurança e eficiência da recarga em seu comércio. 🎶
# ------------------------------------------------------------
#
# 👤 Se eu chegar com meu carro elétrico às 18h em um ponto de carregamento e o sistema estiver em Modo de Prioridade Solar, o que acontece com a velocidade da minha recarga?
# 🤖 Como o sistema está em Modo de Prioridade Solar, a carga será reduzida para não ultrapassar o limite contratado do posto. O tempo estimado de conclusão da recarga pode ser prolongado dependendo da demanda solar e do consumo total do posto. ⛅️
# ------------------------------------------------------------
#
# 👤 A IA consegue prever quando o eletroposto vai estar mais lotado?
# 🤖 Sim, a ChargeGrid Intelligence tem uma função de predição de demanda que analisa os padrões de uso do posto e prevê as horas em que é mais provável que haja um aumento na demanda. Isso permite que você planeje melhor a sua gestão diária e tome medidas para evitar congestionamentos. 📊
# ------------------------------------------------------------
#
# 👤 O que o sistema faz se eu tentar carregar meu carro e o prédio já estiver usando muita energia?
# 🤖 O ChargeGrid Intelligence é projetado para evitar sobrecarga no posto. Se a demanda de energia for alta, o sistema priorizará a distribuição da carga entre os veículos conectados, evitando que um carro consiga carregar mais do que o permitido. Isso garante a estabilidade e segurança da rede elétrica. 💡
# ------------------------------------------------------------
#
# 👤 Quais os benefícios de usar o Modo de Operação 2 (Prioridade Solar)?
# 🤖 O Modo de Operação 2 (Prioridade Solar) prioriza a utilização da energia solar quando disponível, reduzindo assim o consumo de energia da rede. Isso ajuda a minimizar os custos e a contribuir para um uso mais sustentável da energia renovável. ☀️
# ------------------------------------------------------------
#
# 👤 Estou vendo faíscas saindo do conector do carro agora, o que eu faço?
# 🤖 PARA DE IMEDIATAMENTE! Desligue o disjuntor do equipamento e retire o cabo do veículo. Não toque mais no conector até que a situação seja avaliada e resolvida por um técnico treinado. ⚠️
# ------------------------------------------------------------
#
# 👤 O carregador parou de funcionar e tem uma luz vermelha piscando, qual o procedimento?
# 🤖 Desligue imediatamente o disjuntor do equipamento para evitar riscos de fogo ou danos ao sistema. Em seguida, tente realizar um reset do carregador seguindo as instruções específicas do modelo. Caso não haja resposta, contate o suporte técnico GoodWe para obter orientação adicional. 🔴
# ------------------------------------------------------------
